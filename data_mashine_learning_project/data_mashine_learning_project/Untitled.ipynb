# %%
import pandas as pd

# %%
p = pd.read_csv('Bevölkerung - Deutschland.csv')

# %%
p
# Out:
#    Bevölkerung - Deutschland         Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                        NaN               2022        NaN        NaN
# 1                        NaN  Bevölkerungsstand        NaN        NaN
# 2                        NaN             Gesamt   männlich   weiblich
# 3                        NaN             Anzahl     Anzahl     Anzahl
# 4                Deutschland          84358 845  41559 052  42799 793
# 5          Baden-Württemberg          11280 257   5595 424   5684 833
# 6                     Bayern          13369 393   6620 203   6749 190
# 7                     Berlin           3755 251   1843 196   1912 055
# 8                Brandenburg           2573 135   1265 151   1307 984
# 9                     Bremen             684864     338233     346631
# 10                   Hamburg           1892 122     925616     966506
# 11                    Hessen           6391 360   3151 158   3240 202
# ...
